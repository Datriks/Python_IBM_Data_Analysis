# %% [markdown]
# You will analyze and predict housing prices using attributes or features such as square footage, number of bedrooms, number of floors, and so on. A template notebook is provided in the lab; your job is to complete the ten questions.

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %% [markdown]
# ## Module_1 : Import the dataset

# %%
file_path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/FinalModule_Coursera/data/kc_house_data_NaN.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# Check top rows

# %%
df.head()
# Out:
#    Unnamed: 0          id             date     price  bedrooms  bathrooms  \
# 0           0  7129300520  20141013T000000  221900.0       3.0       1.00
# 1           1  6414100192  20141209T000000  538000.0       3.0       2.25
# 2           2  5631500400  20150225T000000  180000.0       2.0       1.00
# 3           3  2487200875  20141209T000000  604000.0       4.0       3.00
# 4           4  1954400510  20150218T000000  510000.0       3.0       2.00
#
#    sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0         1180      5650     1.0           0  ...      7        1180
# 1         2570      7242     2.0           0  ...      7        2170
# 2          770     10000     1.0           0  ...      6         770
# 3         1960      5000     1.0           0  ...      7        1050
# 4         1680      8080     1.0           0  ...      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %% [markdown]
# Display the data types of all the features in the dataframe:

# %%
df.dtypes.to_frame()
# Out:
#                      0
# Unnamed: 0       int64
# id               int64
# date            object
# price          float64
# bedrooms       float64
# bathrooms      float64
# sqft_living      int64
# sqft_lot         int64
# floors         float64
# waterfront       int64
# view             int64
# condition        int64
# grade            int64
# sqft_above       int64
# sqft_basement    int64
# yr_built         int64
# yr_renovated     int64
# zipcode          int64
# lat            float64
# long           float64
# sqft_living15    int64
# sqft_lot15       int64

# %% [markdown]
# Find the number of rows and columns that the dataframe contain

# %%
df.shape
# Out:
# (21613, 22)

# %% [markdown]
# Obtain a statistical summary of the data frame

# %%
df.describe()
# Out:
#         Unnamed: 0            id         price      bedrooms     bathrooms  \
# count  21613.00000  2.161300e+04  2.161300e+04  21600.000000  21603.000000
# mean   10806.00000  4.580302e+09  5.400881e+05      3.372870      2.115736
# std     6239.28002  2.876566e+09  3.671272e+05      0.926657      0.768996
# min        0.00000  1.000102e+06  7.500000e+04      1.000000      0.500000
# 25%     5403.00000  2.123049e+09  3.219500e+05      3.000000      1.750000
# 50%    10806.00000  3.904930e+09  4.500000e+05      3.000000      2.250000
# 75%    16209.00000  7.308900e+09  6.450000e+05      4.000000      2.500000
# max    21612.00000  9.900000e+09  7.700000e+06     33.000000      8.000000
#
#         sqft_living      sqft_lot        floors    waterfront          view  \
# count  21613.000000  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean    2079.899736  1.510697e+04      1.494309      0.007542      0.234303
# ...

# %% [markdown]
# ## Module_2 : Data Wrangling

# %% [markdown]
# Drop the columns "Unnamed: 0" and "id"

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'date', 'price', 'bedrooms', 'bathrooms',
#        'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition',
#        'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated',
#        'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df1 = df.drop(['id', 'Unnamed: 0'], axis=1)
df1.head()
# Out:
#               date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  20141013T000000  221900.0       3.0       1.00         1180      5650
# 1  20141209T000000  538000.0       3.0       2.25         2570      7242
# 2  20150225T000000  180000.0       2.0       1.00          770     10000
# 3  20141209T000000  604000.0       4.0       3.00         1960      5000
# 4  20150218T000000  510000.0       3.0       2.00         1680      8080
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# 1     2.0           0     0          3      7        2170            400
# 2     1.0           0     0          3      6         770              0
# 3     1.0           0     0          5      7        1050            910
# 4     1.0           0     0          3      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df1.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# Find the number of missing numbers in the columns "bedrooms" and "bathrooms"

# %%
print('number of NAN values in bedrooms are: ', df1['bedrooms'].isnull().sum())
print('number of NAN values in bathrooms are: ', df1['bathrooms'].isnull().sum())
# Out:
# number of NAN values in bedrooms are:  13
# number of NAN values in bathrooms are:  10

# %% [markdown]
# Rplace the NAN values with the value oh that fature mean

# %%
mean_bed = df1['bedrooms'].mean()
df1['bedrooms'].replace(np.nan, mean_bed, inplace = True)

# %%
mean_bath = df1['bathrooms'].mean()
df1['bathrooms'].replace(np.nan, mean_bath, inplace = True)

# %%
print('number of NAN values in bedrooms are: ', df1['bedrooms'].isnull().sum())
print('number of NAN values in bathrooms are: ', df1['bathrooms'].isnull().sum())
# Out:
# number of NAN values in bedrooms are:  0
# number of NAN values in bathrooms are:  0

# %% [markdown]
# ## Module_3 : Exploratory Data Analysis

# %%
floor_val = df1['floors'].value_counts()
floor_val.to_frame()
# Out:
#      floors
# 1.0   10680
# 2.0    8241
# 1.5    1910
# 3.0     613
# 2.5     161
# 3.5       8

# %% [markdown]
# Compare the two categories of the houses

# %%
plt.rcParams['figure.figsize'] = (15,6)

# %%
sns.boxenplot(x = 'waterfront', y= 'price', data = df1)

plt.title('Waterfront category vs Price')
plt.xlabel('waterfront')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %% [markdown]
# Use the regplot function to create a regresion plot to determine if the feature sqrt_above is negatively or positively correlated with price

# %%
sns.regplot(x ='sqft_above', y = 'price', line_kws={'color': 'red'}, data = df1)

plt.title('Sqft_above vs Price')
plt.xlabel('sqft_above')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %% [markdown]
# We can find the feature other than price that is correlated with price.

# %%
df1.corr()['price'].sort_values()
# Out:
# zipcode         -0.053203
# long             0.021626
# condition        0.036362
# yr_built         0.054012
# sqft_lot15       0.082447
# sqft_lot         0.089661
# yr_renovated     0.126434
# floors           0.256794
# waterfront       0.266369
# lat              0.307003
# bedrooms         0.308797
# sqft_basement    0.323816
# view             0.397293
# bathrooms        0.525738
# sqft_living15    0.585379
# sqft_above       0.605567
# grade            0.667434
# sqft_living      0.702035
# price            1.000000
# Name: price, dtype: float64

# %% [markdown]
# Here we can visualise the entire correlation table between all features.

# %%
df1.corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.308797   0.525738     0.702035  0.089661  0.256794
# bedrooms       0.308797  1.000000   0.514194     0.578077  0.032307  0.178022
# bathrooms      0.525738  0.514194   1.000000     0.755371  0.087929  0.502132
# sqft_living    0.702035  0.578077   0.755371     1.000000  0.172826  0.353949
# sqft_lot       0.089661  0.032307   0.087929     0.172826  1.000000 -0.005201
# floors         0.256794  0.178022   0.502132     0.353949 -0.005201  1.000000
# waterfront     0.266369 -0.006800   0.063744     0.103818  0.021604  0.023698
# view           0.397293  0.080058   0.188341     0.284611  0.074710  0.029444
# condition      0.036362  0.026690  -0.126197    -0.058753 -0.008958 -0.263768
# grade          0.667434  0.356589   0.664676     0.762704  0.113621  0.458183
# sqft_above     0.605567  0.479286   0.686309     0.876597  0.183512  0.523885
# ...

# %% [markdown]
# ## Module_4 : Model Development

# %% [markdown]
# We can fit a linear regression using the feature 'long' - longitude and evaluate the model

# %%
x = df1[['long']]
y = df1[['price']]

lm = LinearRegression()

model = lm.fit(x, y)

print('R^2 = ', model.score(x, y)*100, '%')
# Out:
# R^2 =  0.04676943014900736 %

# %% [markdown]
# Create a new model based on te feature 'sqft_living' and 'price'

# %%
# another way of transforming series into array instead of using [[]] which is easiear
x1 = df1['sqft_living'].array.reshape(-1, 1)
y1 = df1['price'].array.reshape(-1, 1)

lm1 = LinearRegression()

model1 = lm1.fit(x1, y1)

print('R^2 = ', model1.score(x1, y1)*100, '%')
# Out:
# R^2 =  49.285321790379314 %

# %% [markdown]
# Let's see if the model improves - value of R^2 is higher - if we use a large number of features.

# %%
features = ['floors', 'waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms', 'sqft_living15', 'grade', 'sqft_living']

# %%
x2 = df1[features]
y2 = df1[['price']]

lm2 = LinearRegression()

model2 = lm2.fit(x2, y2)

R2 = model2.score(x2, y2)
print('R^2 = ', R2*100 , '%')
# Out:
# R^2 =  65.76951666037496 %

# %% [markdown]
# Create a polynomial model using pipe
# The first element of the tuple is the estimator
# The second element of tupple is the model constructor

# %%
Input = [('scale', StandardScaler()), 
         ('polynomial', PolynomialFeatures(include_bias = False)), 
         ('model', LinearRegression())]

# %% [markdown]
# Let's use the PipeLine object to predict the price , fit the object using the feature 'features' and calculate R^2

# %%
pipe = Pipeline(Input)
pipe
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynmial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %%
model_pipe = pipe.fit(x2, y2)

# %%
R_pipe = model_pipe.score(x2, y2)
print('R^2 = ', R_pipe * 100, '%')
# Out:
# R^2 =  75.13408521145485 %

# %% [markdown]
# Practice with highest corelated features to price

# %%
features1 = ['bedrooms', 'sqft_basement', 'view', 'bathrooms', 'sqft_living15', 'sqft_above', 'grade', 'sqft_living']

x3 = df1[features1]
y3 = df1[['price']]

Input = [('scale', StandardScaler()), 
         ('polynomial', PolynomialFeatures(include_bias = False)), 
         ('model', LinearRegression())]


pipe1 = Pipeline(Input)

model_pipe1 = pipe1.fit(x3,y3)

R_pipe1 = model_pipe1.score(x3, y3)
print('R^2 = ', R_pipe1 * 100, '%')
# Out:
# R^2 =  64.95274370112222 %

# %% [markdown]
# ## Model_5 : Model Evaluation and Refinement

# %% [markdown]
# Import the necessary modules

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
print('done')
# Out:
# done

# %% [markdown]
# Split the dta into training and testing data

# %%
features = ['floors', 'waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms', 'sqft_living15', 'grade', 'sqft_living']
x4 = df1[features]
y4 = df1[['price']]

x_train, x_test, y_train, y_test = train_test_split(x4, y4, test_size=0.15, random_state=1)

print('number of train_sample : ', x_train.shape[0])
print('number of test sample : ', x_test.shape[0])
# Out:
# number of train_sample :  18371
# number of test sample :  3242

# %% [markdown]
# Create and fit a Ridge Regression object using the training dataset with a regularisation parameter set to 0.1 and calculate R^2 using the test data.

# %%
from sklearn.linear_model import Ridge

# %%
Ridge1 = Ridge(alpha=0.1)

RidgeModel = Ridge1.fit(x_train, y_train)
R_ridge = RidgeModel.score(x_test, y_test)

print('R^2 = ', R_ridge * 100, '%')
# Out:
# R^2 =  64.78759163941896 %

# %% [markdown]
# Perform a second order polynomial transform on both the training data and testing data
# Create and fit a Ridge regression object using the training data
# Set the regularisation to 0.1
# Calculate R^2 utilising the test data provided

# %%
pr = PolynomialFeatures(degree = 2)

x_train_pr = pr.fit_transform(x_train)
x_test_pr = pr.fit_transform(x_test)

Ridge2 = Ridge(alpha = 0.1)

RidgeModel2 = Ridge2.fit(x_train_pr, y_train)

R_ridge2 = RidgeModel2.score(x_test_pr, y_test)
print('R^2 = ', R_ridge2 * 100, '%')
# Out:
# R^2 =  70.02744289308764 %
# C:\ProgramData\Miniconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=7.72846e-20): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
